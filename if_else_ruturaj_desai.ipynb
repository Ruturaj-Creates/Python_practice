# %% [markdown]
# ### 1. Write a program to check if a number is positive.

# %%
num=int(input())
if num>0:
    print("positive")
else:
    print("negative")
# Out:
# positive

# %% [markdown]
# ### 2. Check if a number is even or odd.

# %%
num=int(input())
if num%2==0:
    print("EVEN")
else:
    print("ODD")
# Out:
# EVEN

# %% [markdown]
# ### 3. Check if a person is eligible to vote (age >= 18).

# %%
age=int(input())
if age>=18:
    print("Eligible")
else:
    print("Not eligible")
# Out:
# Not eligible

# %% [markdown]
# ### 4. Check if a number is greater than 100.

# %%
num=int(input())
if num>100:
    print("Greater than 100")
else:
    print("Smaller")
# Out:
# Smaller

# %% [markdown]
# ### 5. Print “Adult” if age > 18 else print “Child”.

# %%
age=int(input())
if age>=18:
    print("adult")
else:
    print("child")
# Out:
# child

# %% [markdown]
# ### 6. Check if two numbers are equal.

# %%
num1=int(input())
num2=int(input())
if num1==num2:
    print("Equal")
else:
    print("Not Equal")
# Out:
# Not Equal

# %% [markdown]
# ### 7. Check if a number is divisible by 5.

# %%
num=int(input())
if num%5==0:
    print("Divisible by 5")
else:
    print("Not divisible by 5")
# Out:
# Not divisible by 5

# %% [markdown]
# ### 8. Check if a string is “hello”.

# %%
st=input("enter phrase")
if st=="hello":
    print("string is hello")
else:
    print("Not")
# Out:
# string is hello

# %% [markdown]
# ### 9. Print the larger of two numbers.

# %%
num1=int(input())
num2=int(input())
if num1>num2:
    print(f"{num1} is larger")
else:
    print(f"{num2} is larger")
# Out:
# 30 is larger

# %% [markdown]
# ### 10. Check if a number is negative

# %%
num=int(input())
if num<0:
    print("negative")
else:
    print("positive")
# Out:
# negative

# %% [markdown]
# ### 11. Check if a number is positive, negative, or zero.

# %%
num=int(input())
if num>0:
    print("positive")
elif num<0:
    print("negative")
else: 
    print("zero")
# Out:
# zero

# %% [markdown]
# ### 12. Check if a year is a leap year.

# %%
year=int(input())
if year%4==0:
    print("Leap year")
else:
    print("Not a leap year")
# Out:
# Leap year

# %% [markdown]
# ### 13. Check if a character is a vowel or consonant.

# %%
vowel=["a","e","i","o","u"]
char=input("enter char")
if char in vowel:
    print("Its a vowel")
else:
    print("consonant")
# Out:
# Its a vowel

# %% [markdown]
# ### 14. Print the greatest of three numbers.

# %%
num1=100
num2=1200
num3=3000

if num1>num2:
    if num1>num3:
        print(f"{num1} is biggest")
    elif num1<num3:
        print(f"{num3} is biggest")
else:
    if num2>num3:
        print(f"{num2} is biggest")
    elif num2<num3:
        print(f"{num3} is biggest")
# Out:
# 3000 is biggest

# %% [markdown]
# ### 15. Check if a password length is strong (>= 8).

# %%
passw=input("enter password")
if len(passw)>=8:
    print("strong password")
else:
    print("password is weak")
# Out:
# strong password

# %% [markdown]
# ### 16. Check if a number lies between 10 and 50.

# %%
num=int(input("enter num"))
if num<=50 and num>=10:
    print(f"{num} is between 10 to 50")
else:
    print(f"{num} is not betweeen 10 to 50")
# Out:
# 51 is not betweeen 10 to 50

# %% [markdown]
# ### 17. Print the grade of a student (A, B, C, D, F) based on marks.

# %%
marks=int(input("enter marks"))
if marks>90:
    print("A")
elif marks>=80 and marks <90:
    print("B")
elif marks >=70 and marks <80:
    print("C")
elif marks >=35 and marks <70:
    print("D")
elif marks < 34:
    print("F")
# Out:
# B

# %% [markdown]
# ### 18. Check if a number is divisible by both 2 and 3.

# %%
num=int(input("enter number"))
if num%3==0 and num%6==0:
    print("Divisible by Both")
else:
    print("Not divisible by both")
# Out:
# Not divisible by both

# %% [markdown]
# ### 19. Check if a person’s age falls into categories: child, teen, adult, senior.

# %%
age=int(input("age"))
if age>=60:
    print("Senior citizen")
elif age<60 and age>18:
    print("adult")
elif age>=11 and age<=18:
    print("Teenager")
elif age>0 and age<10:
    print("child")
else:
    print("eror")
# Out:
# eror

# %% [markdown]
# ### 20. Check if a character is uppercase or lowercase.

# %%
words="abcd"
if words==words.lower():
    print("char is in LOWERCASE")

elif words==words.upper():
    print("char is in UPPERCASE")
# Out:
# char is in LOWERCASE

# %% [markdown]
# ### 21. Check if a number is a multiple of 10.

# %%
num=int(input("enter"))
if num%10==0:
    print('Multiple of 10')
else:
    print("Not a multiple of 10")
# Out:
# Not a multiple of 10

# %% [markdown]
# ### 22. Compare two numbers and print “greater”, “smaller”, or “equal”.

# %%
num1=int(input("enter num"))
num2=int(input("enter num"))
if num1>num2:
    print(f"{num1} is greater than {num2}")
elif num1==num2:
    print(f"{num1} and {num2} are equal")
else:
    print(f"{num1} is smaller than {num2}")
# Out:
# 20 is greater than 15

# %% [markdown]
# ### 23. Check if a triangle is equilateral, isosceles, or scalene.

# %%
a=11                                      
b=25                                            
c=18
if a==b and b==c and a==c:
    print("equilateral")
elif a==b or b==c or a==c:
    print("isoceles")
else:
    print("scalene")
# Out:
# scalene

# %% [markdown]
# ### 24. Check if a string contains the word “python”.

# %%
word=input("enter sentecnce")
if "python" in word:
    print("python is present")
else:
    print("Is not present")
# Out:
# python is present

# %% [markdown]
# ### 25. Check if a list has more than 5 elements.

# %%
lst=[2,5,8,10,13,15,18]
if len(lst)>5 :
    print("More than 5 elements")
else:
    print("less than 5 elements")
# Out:
# less than 5 elements

# %% [markdown]
# ### 26. Check if temperature is cold (<15), warm (15–30), or hot (>30).

# %%
temp=int(input("temp"))
if temp<15:
    print("Cold")
elif temp>=15 and temp<30:
    print("warm")
else:
    print("Hot")
# Out:
# Cold

# %% [markdown]
# ### 27. Check if a student passed (marks >= 40) else fail.

# %%
marks=int(input("enter marks"))
if marks>=40:
    print("student is passed")
else:
    print("student Failed")
# Out:
# student Failed

# %% [markdown]
# ### 28. Check if a number ends with digit 7.

# %%
nums=input("num")
if nums.endswith("7"):
    print("yes, Ends with 7")
else:
    print("no")
# Out:
# yes, Ends with 7

# %% [markdown]
# ### 29. Check if the first character of a string is a vowel.

# %%
word="otters are great swimmers"
vowel=["a","e","o","u","i"]
if word[0] in vowel:
    print("vOWEL")
else:
    print("consonant")
# Out:
# consonant

# %% [markdown]
# ### 30. Check if a number is within 1 to 100, else print “out of range

# %%
num=101
if num>0 and num<=100:
    print("In range")
else:
    print("Out of range")
# Out:
# Out of range

# %% [markdown]
# ### 31. Check if a number is prime using if-else (simple logic allowed).

# %%
                                                                                            #revise

# %% [markdown]
# ### 32. Check if the last digit of a number is even or odd.

# %%
numb=23457
if numb%2==0:
    print("last digit is EVEN")
else:
    print("last digit is ODD")
# Out:
# last digit is ODD

# %% [markdown]
# ### 33. Check if the input is an integer or not (using string checks).

# %%
number="2"
if isinstance(number,int):                                                 
    print("Integer")
else:
    print("Not a int")
# Out:
# Not a int

# %% [markdown]
# ### 34. Check if three angles can form a valid triangle.

# %%
side1=10
side2=20
side3=150
if side1+side2+side3==180:
    print("It is a triangle")
else: 
    print("it is not a triangle")
# Out:
# It is a triangle

# %% [markdown]
# ### 35. Check if two strings are anagrams (simple: check sorted equality).

# %%
""" anagrams:
a word or phrase that is made by arranging the letters of another word or phrase in a different order
Listen: becomes silent """                                                                                            

str1="worth"
str2="throw"
if sorted(str1)==sorted(str2):
    print("Anagrams")
else:
    print("Not anagrams")
# Out:
# Anagrams

# %% [markdown]
# ### 36. Determine the type of triangle using sides: acute, right, obtuse.

# %%
a=45
b=45
c=90
if a+b+c==180:
    if a==90 or b==90 or c==90:
        print("right angled triangle")
    elif a<90 and b<90 and c<90:
        print("Accute angled triangle")
    else:
        print("Obtuse triangle")
    
else:
    print("error,a+b+c!=180 ")
# Out:
# right angled triangle

# %% [markdown]
# ### 37. Check if a string is palindrome (case insensitive).

# %%
word="racecar"
if word[::]==word[::-1]:
    print("palindrome")
else:
    print("Not a palindrome")
# Out:
# palindrome

# %% [markdown]
# ### 38. Check if the first and last characters of a string are same.

# %%
words="wpw"
if words[0:1:]==words[:1:-1]:
    print("1st and last char are same")
else:
    print("first and last char are not same")
# Out:
# 1st and last char are same

# %% [markdown]
# ### 39. Check if the sum of digits of a number is divisible by 3.

# %%
num=38                  # divisibilty test of 3
if num%3==0:
    print("divisible by 3")
else:
    print("not divisible")
# Out:
# not divisible

# %% [markdown]
# ### 40. Check if a number is Armstrong (3-digit).

# %%
"""An Armstrong number is a number that is equal to the sum of its own digits,                                    
 each raised to the power of the total number of digits. For example, 153 is an Armstrong number"""         #revise later

# %% [markdown]
# ### 41. Check if a number has exactly 3 digits.

# %%
digit=123
if len(str(digit))==3:
    print("yes")
else:
    print("no")
# Out:
# yes

# %% [markdown]
# ### 42. Check if a number is perfect (sum of factors equals number).

# %%
                                                                                                        #revise later

# %% [markdown]
# ### 43. Compare lengths of two strings and print which is longer.

# %%
str1="hello"
str2="heyyyy"
if len(str1)>len(str2):
    print(f"{str1} --> is bigger than --> {str2}")
else:
    print(f"{str2} --> is bigger than --> {str1}")
# Out:
# heyyyy --> is bigger than --> hello

# %% [markdown]
# ### 44. Check if a list contains duplicates.

# %%
lst1=[12,11,13,14,12,14]
st=set(lst1)
if lst1==st :
    print("list has no duplicates")
else:
    print("list has duplicate values")
# Out:
# list has duplicate values

# %% [markdown]
# ### 45. Check if a number is both prime AND even (only possible is 2).

# %%
                                                                                                    #revise later

# %% [markdown]
# ### 46. Print “YES” if any of the two numbers is zero else print “NO”.

# %%
num1=1000
num2=00
if num1==0 or num2==0:
    print("yes")
else:
    print("no")
# Out:
# yes

# %% [markdown]
# ### 47. Check if two numbers have the same last digit.

# %%
num1=234
num2=23457
if str(num2)[-1] == str(num1)[-1]:
    print("has same last Digit")
else:
    print("no")
# Out:
# no

# %% [markdown]
# ### 48. Check if a password contains both letters and digits.

# %%
passwd="12dtr"
passwd.isalnum()
# Out:
# True

# %% [markdown]
# ### 49. Check if a number is “lucky”: sum of first two digits equals last two digits.

# %%
                                                                                                            #revise later

# %% [markdown]
# ### 50. Check if the absolute difference between two numbers is less than 10

# %%
num1=65
num2=55
if num1-num2 <=10 :
    print("yes")
else:
    print("no")
# Out:
# yes

# %% [markdown]
# ### 51. Write a program to check if a variable is an integer using isinstance().

# %%
var=35
isinstance(var,int)
# Out:
# True

# %% [markdown]
# ### 52. Check if a given input is a string using isinstance().

# %%
data=input()
isinstance(data,str)
# Out:
# True

# %% [markdown]
# ### 53. Check if a variable is a float and print “Float value found”.

# %%
var2=12.5
isinstance(var2,float)
# Out:
# True

# %% [markdown]
# ### 54. Check if a variable is a list; if yes, print its length.

# %%
var3=[2,4,6,10]
if isinstance(var3,list):
    print("lenght of var3 is:",len(var3))
# Out:
# lenght of var3 is: 4

# %% [markdown]
# ### 55. Write a program to check if a variable is a tuple; if yes, print the first element.

# %%
tp=(2,4,6,10)
if isinstance(tp,tuple):
    print(tp[0])
# Out:
# 2

# %% [markdown]
# ### 56. Check if a variable is a dictionary; if yes, print all keys.

# %%
dic={"name":"abc","roll no":34}
if isinstance(dic,dict):
    print(dic.keys())
# Out:
# dict_keys(['name', 'roll no'])

# %% [markdown]
# ### 57. Check if a variable is a set; if yes, print the number of elements.

# %%
st={2,4,6,10}
if isinstance(st,set):
    print("Total elements is st:",len(st))
# Out:
# Total elements is st: 4

# %% [markdown]
# ### 58. Check if a variable is a boolean and print “True/False detected”.

# %%
bol=True
if isinstance(bol,bool):
    print("True detected")
# Out:
# True detected

# %% [markdown]
# ### 59. Write a program to check if a variable is either int OR float (number check).

# %%
num=13.5
if isinstance(num,int):
    print("variable is INT")
elif isinstance(num,float):
    print("variable is FLOAT")
# Out:
# variable is FLOAT

# %% [markdown]
# ### 60. Check if a variable is NOT a list (using not isinstance()), and print: “Not a list”.

# %%
variable="hello"
if not isinstance(variable, list):
    print("not a list")
else:
    print('List')
# Out:
# not a list
