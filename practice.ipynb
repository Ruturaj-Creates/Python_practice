# %%
print("hello")
# Out:
# hello

# %%
import sys
print(sys.executable)
print("Everything is working!")
# Out:
# e:\SP cyberword\python spc\venv\Scripts\python.exe
# Everything is working!

# %%
print("hello world")
# Out:
# hello world

# %%
print("hello world")
# Out:
# hello world
